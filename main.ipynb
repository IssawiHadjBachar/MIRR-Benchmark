# %%
pip install transformers torch sentence-transformers pandas numpy matplotlib seaborn scikit-learn

# %%
from experiments.behavioral_experiment import run_behavioral_pipeline
from experiments.activation_experiment import run_activation_pipeline
from prompts.prompt_template import build_prompt

required_models = [
    "Qwen/Qwen2.5-0.5B-Instruct",
    "EleutherAI/pythia-410m"
]


run_behavioral_pipeline(required_models, build_prompt)
print("Behavioral experiment completed.")

# %%
import importlib
import evaluation.reasoning_similarity
import experiments.reasoning_experiment

importlib.reload(evaluation.reasoning_similarity)
importlib.reload(experiments.reasoning_experiment)

from experiments.reasoning_experiment import run_reasoning_similarity_pipeline
run_reasoning_similarity_pipeline()
print("Reasoning similarity completed successfully!")

# %%
run_activation_pipeline(required_models, build_prompt)
print("Activation analysis completed.")

# %%
from analysis.find_right_answer_wrong_reason import find_anomalous_behavior
find_anomalous_behavior()
print("RAWR analysis completed.")
# Out:
# RAWR analysis completed.

# %%
from analysis.generate_plots import generate_and_save_plots
from analysis.compare_models import compute_research_findings

generate_and_save_plots()
compute_research_findings()

print("Final analysis completed.")
# Out:
# /content/analysis/generate_plots.py:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_b, x="condition", y="correct", order=["clean", "hinted", "misleading"], errorbar=None, palette="viridis")
# /content/analysis/generate_plots.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_r, x="model", y="reasoning_similarity", errorbar=None, palette="crest")
# All 5 required visual plots saved inside 'results/plots/'.
#
# ...
#  AUTOMATED RESEARCH FINDINGS REPORT
# ...
#
# [Finding 1] Accuracy across Conditions:
# condition                   clean  hinted  misleading
# model
# EleutherAI/pythia-410m        0.1     0.0         0.0
# ...
